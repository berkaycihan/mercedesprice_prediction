# %%
import pandas as pd
df=pd.read_csv('totalDataFrameMerc.csv',encoding='utf-8')
df[:4]
# Out:
#                          adres  \
# 0      İzmir / Buca / Şirinyer
# 1     Konya / Karatay / Merkez
# 2    Adana / Seyhan / Yeşiloba
# 3  İstanbul / Kadıköy / Merkez
#
#                                               baslik       fiyat   ilan_no  \
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...  325.950 TL  #3870263
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...  242.000 TL   #294428
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...  440.000 TL  #3503014
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  239.250 TL  #2259580
#
#   ilan_tarihi  kilometre     kimden     marka     model  model_yili  \
# 0  21/03/2021     41.541  Galeriden  Mercedes  A Serisi        2016
# 1  21/03/2021    102.000  Galeriden  Mercedes  A Serisi        2017
# 2  21/03/2021      0.000  Galeriden  Mercedes  A Serisi        2020
# 3  21/03/2021    160.000  Galeriden  Mercedes  A Serisi        2014
#
#    motor_gucu   motor_hacmi                         varyant  \
# 0  Bilmiyorum  1301-1600 cc                     A 180 d AMG
# 1  Bilmiyorum  1301-1600 cc  A 180 CDI BlueEfficiency Style
# 2  Bilmiyorum  1301-1600 cc                           Diğer
# 3  Bilmiyorum  1301-1600 cc  A 180 CDI BlueEfficiency Urban
#
#             vites_tipi yakit_turu
# 0  Yarı Otomatik Vites      Dizel
# 1       Otomatik Vites      Dizel
# 2  Yarı Otomatik Vites      Dizel
# 3  Yarı Otomatik Vites      Dizel

# %%
df=df.rename(columns={"adres":"city",
                      "baslik":"title",
                      "fiyat":"price_tl",
                      "ilan_no":"adver_number",
                      "ilan_tarihi":"adver_date",
                      "kilometre":"km",
                      "kimden":"from",
                      "marka":"brand",
                      "model":"class_",
                      "model_yili":"year",
                      "motor_gucu":"engine_power",
                      "motor_hacmi":"engine_capacity_cc",
                      "varyant":"variant",
                      "vites_tipi":"gear",
                      "yakit_turu":"fuel"
                      
                      })
df[:5]
# Out:
#                               city  \
# 0          İzmir / Buca / Şirinyer
# 1         Konya / Karatay / Merkez
# 2        Adana / Seyhan / Yeşiloba
# 3      İstanbul / Kadıköy / Merkez
# 4  Denizli / Merkezefendi / Merkez
#
#                                                title    price_tl adver_number  \
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...  325.950 TL     #3870263
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...  242.000 TL      #294428
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...  440.000 TL     #3503014
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  239.250 TL     #2259580
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...  303.750 TL     #1923116
#
#    adver_date       km       from     brand    class_  year engine_power  \
# 0  21/03/2021   41.541  Galeriden  Mercedes  A Serisi  2016   Bilmiyorum
# 1  21/03/2021  102.000  Galeriden  Mercedes  A Serisi  2017   Bilmiyorum
# 2  21/03/2021    0.000  Galeriden  Mercedes  A Serisi  2020   Bilmiyorum
# 3  21/03/2021  160.000  Galeriden  Mercedes  A Serisi  2014   Bilmiyorum
# 4  21/03/2021   91.000  Galeriden  Mercedes  A Serisi  2016   Bilmiyorum
#
#   engine_capacity_cc                         variant                 gear  \
# 0       1301-1600 cc                     A 180 d AMG  Yarı Otomatik Vites
# 1       1301-1600 cc  A 180 CDI BlueEfficiency Style       Otomatik Vites
# 2       1301-1600 cc                           Diğer  Yarı Otomatik Vites
# 3       1301-1600 cc  A 180 CDI BlueEfficiency Urban  Yarı Otomatik Vites
# 4       1301-1600 cc                     A 180 d AMG  Yarı Otomatik Vites
#
#     fuel
# 0  Dizel
# 1  Dizel
# 2  Dizel
# 3  Dizel
# 4  Dizel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 15 columns):
# city                  1017 non-null object
# title                 1028 non-null object
# price_tl              1028 non-null object
# adver_number          1028 non-null object
# adver_date            1028 non-null object
# km                    1028 non-null float64
# from                  1028 non-null object
# brand                 1028 non-null object
# class_                1028 non-null object
# year                  1028 non-null int64
# engine_power          1028 non-null object
# engine_capacity_cc    1028 non-null object
# variant               1028 non-null object
# gear                  1028 non-null object
# fuel                  1028 non-null object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 120.5+ KB

# %%
for i in range(0,len(df.city)):
    try:
        list=df.city[i].split("/")
        df.city[i]=list[0]
    except:
        pass
df.city[5]
# Out:
# C:\Users\Noname\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 'İstanbul '

# %%
df.head()
# Out:
#         city                                              title    price_tl  \
# 0     İzmir   2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...  325.950 TL
# 1     Konya   Özsağlam dan 2017 Mercedes A180 CDI Style 102b...  242.000 TL
# 2     Adana   EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...  440.000 TL
# 3  İstanbul   A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  239.250 TL
# 4   Denizli   AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...  303.750 TL
#
#   adver_number  adver_date       km       from     brand    class_  year  \
# 0     #3870263  21/03/2021   41.541  Galeriden  Mercedes  A Serisi  2016
# 1      #294428  21/03/2021  102.000  Galeriden  Mercedes  A Serisi  2017
# 2     #3503014  21/03/2021    0.000  Galeriden  Mercedes  A Serisi  2020
# 3     #2259580  21/03/2021  160.000  Galeriden  Mercedes  A Serisi  2014
# 4     #1923116  21/03/2021   91.000  Galeriden  Mercedes  A Serisi  2016
#
#   engine_power engine_capacity_cc                         variant  \
# 0   Bilmiyorum       1301-1600 cc                     A 180 d AMG
# 1   Bilmiyorum       1301-1600 cc  A 180 CDI BlueEfficiency Style
# 2   Bilmiyorum       1301-1600 cc                           Diğer
# 3   Bilmiyorum       1301-1600 cc  A 180 CDI BlueEfficiency Urban
# 4   Bilmiyorum       1301-1600 cc                     A 180 d AMG
#
#                   gear   fuel
# 0  Yarı Otomatik Vites  Dizel
# 1       Otomatik Vites  Dizel
# 2  Yarı Otomatik Vites  Dizel
# 3  Yarı Otomatik Vites  Dizel
# 4  Yarı Otomatik Vites  Dizel

# %%
for i in range(0,len(df.price_tl)):
    try:
        df.price_tl[i]=df.price_tl[i].replace(".","")
        df.price_tl[i]=df.price_tl[i].replace("TL","")
    except:
        pass
df.price_tl[5]
# Out:
# C:\Users\Noname\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Noname\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# '278000 '

# %%
df[:5]
# Out:
#         city                                              title price_tl  \
# 0     İzmir   2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...  325950
# 1     Konya   Özsağlam dan 2017 Mercedes A180 CDI Style 102b...  242000
# 2     Adana   EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...  440000
# 3  İstanbul   A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  239250
# 4   Denizli   AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...  303750
#
#   adver_number  adver_date       km       from     brand    class_  year  \
# 0     #3870263  21/03/2021   41.541  Galeriden  Mercedes  A Serisi  2016
# 1      #294428  21/03/2021  102.000  Galeriden  Mercedes  A Serisi  2017
# 2     #3503014  21/03/2021    0.000  Galeriden  Mercedes  A Serisi  2020
# 3     #2259580  21/03/2021  160.000  Galeriden  Mercedes  A Serisi  2014
# 4     #1923116  21/03/2021   91.000  Galeriden  Mercedes  A Serisi  2016
#
#   engine_power engine_capacity_cc                         variant  \
# 0   Bilmiyorum       1301-1600 cc                     A 180 d AMG
# 1   Bilmiyorum       1301-1600 cc  A 180 CDI BlueEfficiency Style
# 2   Bilmiyorum       1301-1600 cc                           Diğer
# 3   Bilmiyorum       1301-1600 cc  A 180 CDI BlueEfficiency Urban
# 4   Bilmiyorum       1301-1600 cc                     A 180 d AMG
#
#                   gear   fuel
# 0  Yarı Otomatik Vites  Dizel
# 1       Otomatik Vites  Dizel
# 2  Yarı Otomatik Vites  Dizel
# 3  Yarı Otomatik Vites  Dizel
# 4  Yarı Otomatik Vites  Dizel

# %%
df = df[['adver_number',"brand","class_","variant","km","engine_capacity_cc","engine_power","fuel","gear","adver_date","from","year","price_tl","title","city"]]
df.head()
# Out:
#   adver_number     brand    class_                         variant       km  \
# 0     #3870263  Mercedes  A Serisi                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A Serisi  A 180 CDI BlueEfficiency Style  102.000
# 2     #3503014  Mercedes  A Serisi                           Diğer    0.000
# 3     #2259580  Mercedes  A Serisi  A 180 CDI BlueEfficiency Urban  160.000
# 4     #1923116  Mercedes  A Serisi                     A 180 d AMG   91.000
#
#   engine_capacity_cc engine_power   fuel                 gear  adver_date  \
# 0       1301-1600 cc   Bilmiyorum  Dizel  Yarı Otomatik Vites  21/03/2021
# 1       1301-1600 cc   Bilmiyorum  Dizel       Otomatik Vites  21/03/2021
# 2       1301-1600 cc   Bilmiyorum  Dizel  Yarı Otomatik Vites  21/03/2021
# 3       1301-1600 cc   Bilmiyorum  Dizel  Yarı Otomatik Vites  21/03/2021
# 4       1301-1600 cc   Bilmiyorum  Dizel  Yarı Otomatik Vites  21/03/2021
#
#         from  year price_tl  \
# 0  Galeriden  2016  325950
# 1  Galeriden  2017  242000
# 2  Galeriden  2020  440000
# 3  Galeriden  2014  239250
# 4  Galeriden  2016  303750
#
#                                                title       city
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...     İzmir
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...     Konya
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...     Adana
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  İstanbul
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...   Denizli

# %%
df.dtypes
# Out:
# adver_number           object
# brand                  object
# class_                 object
# variant                object
# km                    float64
# engine_capacity_cc     object
# engine_power           object
# fuel                   object
# gear                   object
# adver_date             object
# from                   object
# year                    int64
# price_tl               object
# title                  object
# city                   object
# dtype: object

# %%
df_2=df.copy()
df_2.head()
# Out:
#   adver_number     brand    class_                         variant       km  \
# 0     #3870263  Mercedes  A Serisi                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A Serisi  A 180 CDI BlueEfficiency Style  102.000
# 2     #3503014  Mercedes  A Serisi                           Diğer    0.000
# 3     #2259580  Mercedes  A Serisi  A 180 CDI BlueEfficiency Urban  160.000
# 4     #1923116  Mercedes  A Serisi                     A 180 d AMG   91.000
#
#   engine_capacity_cc engine_power   fuel                 gear  adver_date  \
# 0       1301-1600 cc   Bilmiyorum  Dizel  Yarı Otomatik Vites  21/03/2021
# 1       1301-1600 cc   Bilmiyorum  Dizel       Otomatik Vites  21/03/2021
# 2       1301-1600 cc   Bilmiyorum  Dizel  Yarı Otomatik Vites  21/03/2021
# 3       1301-1600 cc   Bilmiyorum  Dizel  Yarı Otomatik Vites  21/03/2021
# 4       1301-1600 cc   Bilmiyorum  Dizel  Yarı Otomatik Vites  21/03/2021
#
#         from  year price_tl  \
# 0  Galeriden  2016  325950
# 1  Galeriden  2017  242000
# 2  Galeriden  2020  440000
# 3  Galeriden  2014  239250
# 4  Galeriden  2016  303750
#
#                                                title       city
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...     İzmir
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...     Konya
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...     Adana
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  İstanbul
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...   Denizli

# %%
df_2.class_.value_counts()
# Out:
# C           494
# E Serisi    380
# A Serisi    114
# B Serisi     38
# EQC           1
# Viano         1
# Name: class_, dtype: int64

# %%
df_2[df_2.class_=='EQC']
# Out:
#     adver_number     brand class_ variant     km engine_capacity_cc  \
# 991     #4596031  Mercedes    EQC     400  543.0    1300 cc ve altı
#
#     engine_power      fuel            gear  adver_date           from  year  \
# 991   401-425 BG  Elektrik  Otomatik Vites  05/03/2021  Araba.com'dan  2020
#
#      price_tl                                      title       city
# 991  1342100   2020 Model 0 km Mercedes EQC 400 - 543 KM  İstanbul

# %%
df_2[df_2.class_=='Viano']
# Out:
#     adver_number     brand class_                         variant     km  \
# 608     #2818677  Mercedes  Viano  2.2 CDI Ambiente Activity Uzun  327.0
#
#     engine_capacity_cc engine_power   fuel            gear  adver_date  \
# 608       2001-2500 cc   151-175 BG  Dizel  Otomatik Vites  16/02/2021
#
#               from  year price_tl  \
# 608  Araba.com'dan  2008  129300
#
#                                                  title       city
# 608  2008 Model 2. El Mercedes Viano 2.2 CDI Ambien...  İstanbul

# %%
df_2=df_2.drop(df.index[[991,608]])
df_2=df_2.reset_index(drop=True)
df_2[605:610]
# Out:
#     adver_number     brand class_               variant      km  \
# 605     #3550090  Mercedes      C  C 220 CDI Avantgarde  134.32
# 606      #957227  Mercedes      C                 Diğer  135.00
# 607      #750007  Mercedes      C                 Diğer  107.00
# 608     #3583415  Mercedes      C        180 Avantgarde  144.00
# 609     #4594061  Mercedes      C      C 180 Avantgarde   52.00
#
#     engine_capacity_cc engine_power    fuel                 gear  adver_date  \
# 605       2001-2500 cc   Bilmiyorum   Dizel       Otomatik Vites  05/02/2021
# 606       1301-1600 cc   Bilmiyorum   Dizel  Yarı Otomatik Vites  05/02/2021
# 607       1301-1600 cc   Bilmiyorum   Dizel       Otomatik Vites  05/02/2021
# 608       1301-1600 cc   151-175 BG  Benzin       Otomatik Vites  12/02/2021
# 609       1301-1600 cc   151-175 BG  Benzin       Otomatik Vites  14/02/2021
#
#            from  year price_tl  \
# 605   Galeriden  2009  227750
# 606   Galeriden  2016  427000
# 607   Galeriden  2017  440000
# 608  Sahibinden  2012  239000
# 609   Galeriden  2016  366900
#
#                                                  title       city
# 605  -EŞİYOK-PENDİK 2009 C 220 CDI Avantgarde Sunro...  İstanbul
# 606  PALA OTO CAM TAVAN BURMESTER CARBON K.HAFIZA E...  İstanbul
# 607  -- BOYASIZ -- Mercedes C - 200 d BlueTEC AMG M...    Amasya
# 608        2012 MERCEDES C180 AVANTGARDE 1.6 7G TRONIC  İstanbul
# 609  UĞUR DAN 2016 C180 AVANTGARDE İMZALI SERİ TOUC...  İstanbul

# %%
df_2[988:994]
# Out:
#     adver_number     brand    class_                            variant  \
# 988     #4641759  Mercedes  E Serisi                          E 200 AMG
# 989      #340445  Mercedes  E Serisi                 E 220 d Avantgarde
# 990      #690132  Mercedes  E Serisi                      E 250 CGI AMG
# 991     #1106368  Mercedes  E Serisi  E 350 CDI BlueEfficiency Elegance
# 992     #4019097  Mercedes  E Serisi                              Diğer
# 993     #4547963  Mercedes  E Serisi                      E 180 Premium
#
#              km engine_capacity_cc engine_power    fuel                 gear  \
# 988      62.459       1801-2000 cc   Bilmiyorum  Benzin  Yarı Otomatik Vites
# 989      15.000    1300 cc ve altı   Bilmiyorum   Dizel       Otomatik Vites
# 990     102.000    1300 cc ve altı   Bilmiyorum  Benzin       Otomatik Vites
# 991     235.000       2501-3000 cc   Bilmiyorum   Dizel  Yarı Otomatik Vites
# 992     137.000       1301-1600 cc   Bilmiyorum  Benzin  Yarı Otomatik Vites
# 993  102854.000       1301-1600 cc   Bilmiyorum  Benzin  Yarı Otomatik Vites
#
#      adver_date       from  year  price_tl  \
# 988  05/02/2021  Galeriden  2016   725000
# 989  05/02/2021  Galeriden  2020  1105000
# 990  05/02/2021  Galeriden  2013   425000
# 991  05/02/2021  Galeriden  2010   400000
# 992  05/02/2021  Galeriden  2016   439900
# 993  05/02/2021  Galeriden  2014   417500
#
#                                                  title       city
# 988  2016 E200 AMG EXCLUSIVE BURMESTER COMAND VAKUM...  İstanbul
# 989  2020 E 220D AVANTGARDE 4 MATIC SUNROOF ISITMA ...  İstanbul
# 990  BOYASIZ HATASIZ E250 COUPE AMG İÇİ KIRMIZI CAM...  İstanbul
# 991  ERMOTOR 2010 MERCEDES E350 AMG HARMAN Mercedes...  Nevşehir
# 992  KARAKILIÇ OTOMOTİV 2016 MERCEDES E180 STYLE IS...   Giresun
# 993  2014 ORJİNAL E180 PREMİUM CAM TAVAN KOLTUKISIT...     İzmir

# %%
df_2.class_.value_counts()
# Out:
# C           494
# E Serisi    380
# A Serisi    114
# B Serisi     38
# Name: class_, dtype: int64

# %%
df_2.head(2)
# Out:
#   adver_number     brand    class_                         variant       km  \
# 0     #3870263  Mercedes  A Serisi                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A Serisi  A 180 CDI BlueEfficiency Style  102.000
#
#   engine_capacity_cc engine_power   fuel                 gear  adver_date  \
# 0       1301-1600 cc   Bilmiyorum  Dizel  Yarı Otomatik Vites  21/03/2021
# 1       1301-1600 cc   Bilmiyorum  Dizel       Otomatik Vites  21/03/2021
#
#         from  year price_tl  \
# 0  Galeriden  2016  325950
# 1  Galeriden  2017  242000
#
#                                                title    city
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...  İzmir
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...  Konya

# %%
print(df_2.brand.value_counts())
print(df_2.variant.value_counts())
print(df_2.engine_capacity_cc.value_counts())
print(df_2.engine_power.value_counts())
print(df_2.fuel.value_counts())
print(df_2.gear.value_counts())
print(df_2['from'].value_counts())
print(df_2.year.value_counts())
print(df_2.city.value_counts())
# Out:
# Mercedes    1026
# Name: brand, dtype: int64
# Diğer                                     276
# C 180 AMG 7G-Tronic                        47
# E 180 Exclusive                            36
# A 180 d AMG                                31
# C 180 Komp. BlueEfficiency AMG             27
# E 180 Elite                                26
# E 200 Komp. Avantgarde                     24
# E 180 Edition E                            22
# E 180 AMG                                  17
# C 180 AMG 9G-Tronic                        17
# C 180 Exclusive                            16
# E 220 d AMG                                15
# A 180 CDI BlueEfficiency Style             15
# C 180 BlueEfficiency Avantgarde            14
# E 200 Elegance                             14
# A 180 AMG Sport                            12
# C 180 Komp. BlueEfficiency Fascination     11
# C 220 CDI Avantgarde                       11
# E 220 CDI Avantgarde                       11
# E 250 AMG 7G-Tronic                        11
# E 220 d Exclusive                          10
# C 180 Komp. BlueEfficiency Avantgarde      10
# C 180 BlueEfficiency AMG                    9
# E 180 Premium                               9
# E 220 d Avantgarde                          9
# A 180 CDI BlueEfficiency AMG                9
# E 250 CDI Edition                           9
# E 250 CDI Premium                           8
# E 200 200                                   8
# E 300 AMG                                   7
#                                          ...
# A 150 Avantgarde                            1
# B 150 Boyut                                 1
# E 320 CDI Avantgarde                        1
# 200 Komp. Elegance                          1
# A 180 CDI BlueEfficiency Prime              1
# E 220 Classic                               1
# E 200 Classic                               1
# A 170 CDI Classic                           1
# C 180 Style                                 1
# 200 BlueEfficiency Avantgarde               1
# E 250 BlueTEC                               1
# C 180 Komp. BlueEfficiency Elegance         1
# 200 Komp. Sportcoupe                        1
# E 250 CDI Avantgarde                        1
# A 150 Polarstar                             1
# 180 BlueEfficiency Fascination              1
# 180 BlueEfficiency Avantgarde               1
# E 200 CGI BlueEfficiency Prime              1
# E 250 CGI Elite                             1
# E 250 CDI Elite Avantgarde                  1
# B 180 CDI BlueEfficiency Urban              1
# 180 Komp. Elegance                          1
# B 180 CDI AMG                               1
# E 240 Elegance                              1
# E 230 Classic                               1
# 180 Komp. BlueEfficiency Sport              1
# 180 Exclusive                               1
# A 170 CDI Elegance                          1
# E 300 300                                   1
# C 200 Komp. Classic                         1
# Name: variant, Length: 139, dtype: int64
# 1301-1600 cc        639
# 1801-2000 cc        120
# 1300 cc ve altı      94
# 1601-1800 cc         76
# 2001-2500 cc         74
# 2501-3000 cc         14
# 3001-3500 cc          7
# 6001 cc ve üzeri      1
# 3501-4000 cc          1
# Name: engine_capacity_cc, dtype: int64
# Bilmiyorum         977
# 151-175 BG          19
# 126-150 BG          18
# 101-125 BG           5
# 176-200 BG           3
# 76-100 BG            2
# 100 BG ve altı       1
# 601 BG ve üzeri      1
# Name: engine_power, dtype: int64
# Benzin        455
# Dizel         427
# Benzin/LPG    144
# Name: fuel, dtype: int64
# Otomatik Vites         568
# Yarı Otomatik Vites    412
# Düz Vites               46
# Name: gear, dtype: int64
# Galeriden     1000
# Sahibinden      26
# Name: from, dtype: int64
# 2016    170
# 2017    132
# 2015    121
# 2018     97
# 2011     67
# 2014     66
# 2012     57
# 2013     48
# 2010     43
# 2020     40
# 2008     18
# 1996     17
# 2001     15
# 2009     15
# 2004     13
# 1998     13
# 2006     12
# 1994     12
# 1997     10
# 2007     10
# 2003     10
# 2005     10
# 1995      8
# 2002      5
# 2000      5
# 1993      3
# 1987      2
# 1989      1
# 1986      1
# 2021      1
# 1990      1
# 1999      1
# 2019      1
# 1985      1
# Name: year, dtype: int64
# İstanbul          477
# Ankara             71
# Gaziantep          39
# Konya              37
# İzmir              34
# Adana              29
# Kocaeli            26
# Kilis              20
# İstanbul           17
# Denizli            16
# Antalya            14
# Hatay              14
# Mersin             13
# Bursa              11
# Giresun            11
# Samsun             10
# Aydın              10
# Şanlıurfa           9
# Malatya             8
# Ordu                8
# İzmir               8
# Kayseri             7
# Konya               7
# Düzce               6
# Mersin              6
# Van                 5
# Balıkesir           5
# Elazığ              5
# Amasya              5
# Nevşehir            4
#                  ...
# Kahramanmaraş       3
# Çorum               3
# Trabzon             3
# Diyarbakır          3
# Kocaeli             3
# Zonguldak           2
# Siirt               2
# Kırıkkale           2
# Sakarya             2
# Kırşehir            2
# Adana               2
# Rize                2
# Denizli             2
# Erzincan            2
# Muğla               1
# Çankırı             1
# Mardin              1
# Aksaray             1
# Burdur              1
# Mardin              1
# Şanlıurfa           1
# Erzurum             1
# Düzce               1
# Tokat               1
# Yozgat              1
# Ağrı                1
# Kütahya             1
# Isparta             1
# Sivas               1
# Eskişehir           1
# Name: city, Length: 69, dtype: int64

# %%
print(df_2.engine_capacity_cc.value_counts())
# Out:
# 1301-1600 cc        639
# 1801-2000 cc        120
# 1300 cc ve altı      94
# 1601-1800 cc         76
# 2001-2500 cc         74
# 2501-3000 cc         14
# 3001-3500 cc          7
# 6001 cc ve üzeri      1
# 3501-4000 cc          1
# Name: engine_capacity_cc, dtype: int64

# %%
df_2[df_2.engine_capacity_cc=='3501-4000 cc']
# Out:
#      adver_number     brand    class_   variant    km engine_capacity_cc  \
# 1003     #3222257  Mercedes  E Serisi  E 63 AMG  24.0       3501-4000 cc
#
#          engine_power    fuel            gear  adver_date       from  year  \
# 1003  601 BG ve üzeri  Benzin  Otomatik Vites  16/02/2021  Galeriden  2018
#
#       price_tl          title    city
# 1003  2475000   YER UÇAGI E63  Hatay

# %%
df_2[df_2.engine_capacity_cc=='6001 cc ve üzeri']
# Out:
#     adver_number     brand class_                        variant     km  \
# 289     #2835644  Mercedes      C  180 BlueEfficiency Avantgarde  243.0
#
#     engine_capacity_cc engine_power        fuel       gear  adver_date  \
# 289   6001 cc ve üzeri   151-175 BG  Benzin/LPG  Düz Vites  01/03/2021
#
#            from  year price_tl         title        city
# 289  Sahibinden  2009  212500   KRAL SATIŞTA  Kırıkkale

# %%
df_2=df_2.drop(df.index[[1003,289]])
df_2=df_2.reset_index(drop=True)
df_2[285:291]
# Out:
#     adver_number     brand class_              variant       km  \
# 285      #107235  Mercedes      C      200 BlueTEC AMG   95.000
# 286     #3614216  Mercedes      C        180 Exclusive  125.000
# 287     #2011083  Mercedes      C  C 180 AMG 7G-Tronic   22.000
# 288     #3716681  Mercedes      C                Diğer   88.000
# 289     #1607836  Mercedes      C                Diğer  108.000
# 290     #4516804  Mercedes      C     C 180 Avantgarde  113.767
#
#     engine_capacity_cc engine_power    fuel            gear  adver_date  \
# 285       1601-1800 cc   126-150 BG   Dizel  Otomatik Vites  23/02/2021
# 286       1301-1600 cc   151-175 BG  Benzin  Otomatik Vites  24/02/2021
# 287       1301-1600 cc   126-150 BG  Benzin  Otomatik Vites  28/02/2021
# 288       1301-1600 cc   Bilmiyorum   Dizel  Otomatik Vites  01/03/2021
# 289       1301-1600 cc   Bilmiyorum   Dizel  Otomatik Vites  01/03/2021
# 290       1301-1600 cc   Bilmiyorum  Benzin  Otomatik Vites  02/03/2021
#
#            from  year price_tl  \
# 285  Sahibinden  2015  420000
# 286   Galeriden  2014  389900
# 287   Galeriden  2016  525000
# 288   Galeriden  2017  389750
# 289   Galeriden  2017  345000
# 290   Galeriden  2015  333900
#
#                                                  title       city
# 285      HATASIZ BOYASIZ C200AMG ÖZEL SERI ANALOG SAAT     Hatay
# 286  SÜRMENE OTOMOTİV DEN ISITMA SUNROOF CAM TAVAN ...  İstanbul
# 287  İLK EL SIFIRDAN FARKSIZ-MERCEDES BENZ C 180 AM...    Elazığ
# 288  EXTRA AMG JANTLI HATASIZ BOYASIZ ORJİNAL DİZEL...  İstanbul
# 289  ORJİNAL HATASIZ 2017 MERCEDES-BENZ C 200 D Blu...  İstanbul
# 290  ASAL OTOMOTİVDEN 2015 MERCEDES C 180 1.6 AVANT...    Samsun

# %%
df_2[1000:1005]
# Out:
#      adver_number     brand    class_               variant     km  \
# 1000     #1327296  Mercedes  E Serisi  E 200 Komp. Elegance  157.0
# 1001     #3449286  Mercedes  E Serisi  E 220 CDI Avantgarde  270.0
# 1002     #2722123  Mercedes  E Serisi     E 180 AMG Premium  138.0
# 1003     #2691912  Mercedes  E Serisi     E 250 CDI Premium  168.0
# 1004     #4398784  Mercedes  E Serisi             E 180 AMG   31.0
#
#      engine_capacity_cc engine_power    fuel                 gear  adver_date  \
# 1000       1601-1800 cc   Bilmiyorum  Benzin  Yarı Otomatik Vites  15/02/2021
# 1001       2001-2500 cc   Bilmiyorum   Dizel  Yarı Otomatik Vites  16/02/2021
# 1002       1301-1600 cc   151-175 BG  Benzin       Otomatik Vites  24/02/2021
# 1003       2001-2500 cc   Bilmiyorum   Dizel  Yarı Otomatik Vites  21/03/2021
# 1004       1301-1600 cc   Bilmiyorum  Benzin       Otomatik Vites  21/03/2021
#
#            from  year price_tl  \
# 1000  Galeriden  2003  193000
# 1001  Galeriden  2009  290000
# 1002  Galeriden  2014  399900
# 1003  Galeriden  2012  364750
# 1004  Galeriden  2018  650000
#
#                                                   title       city
# 1000  2003 E 200 KOMP ELEGANCE 157.000 Km de Mercede...   Denizli
# 1001  2010 MODEL 1 PARÇA BOYALI HATASIZ 220 CDİ Merc...    Yozgat
# 1002  SÜRMENE OTOMOTİV DEN DERİ ISITMA HAFIZA ŞERİT ...  İstanbul
# 1003  168.000 KM.DE FULL FULL MAKYAJLI KASA E250 7 İ...  İstanbul
# 1004  2019 AMG EXCLUSİVE CAM TAVAN VAKUM COMMAND BAY...  İstanbul

# %%
print(df_2.fuel.value_counts())
# Out:
# Benzin        454
# Dizel         427
# Benzin/LPG    143
# Name: fuel, dtype: int64

# %%
df_2.loc[df_2.fuel == "Benzin", "fuel"] = "Petrol"
df_2.loc[df_2.fuel == "Dizel", "fuel"] = "Diesel"
df_2.loc[df_2.fuel == "Benzin/LPG", "fuel"] = "Petrol"
print(df_2.fuel.value_counts())
# Out:
# Petrol    597
# Diesel    427
# Name: fuel, dtype: int64

# %%
df_2.tail(3)
# Out:
#      adver_number     brand    class_                              variant  \
# 1021     #4590792  Mercedes  E Serisi  E 250 CDI BlueEfficiency Avantgarde
# 1022     #4324911  Mercedes  E Serisi                          E 180 Elite
# 1023     #2798325  Mercedes  E Serisi                        E 250 BlueTEC
#
#          km engine_capacity_cc engine_power    fuel                 gear  \
# 1021  302.0       2001-2500 cc   Bilmiyorum  Diesel  Yarı Otomatik Vites
# 1022   80.2       1301-1600 cc   Bilmiyorum  Petrol  Yarı Otomatik Vites
# 1023  150.0       1801-2000 cc   126-150 BG  Petrol       Otomatik Vites
#
#       adver_date       from  year price_tl  \
# 1021  21/03/2021  Galeriden  2010  310000
# 1022  21/03/2021  Galeriden  2013  389000
# 1023  22/03/2021  Galeriden  2015  525000
#
#                                                   title     city
# 1021  KARAELMAS DAN E250 CDI ÇİFT HAREKET HAFIZA CAM...   Kilis
# 1022  2013 MERCEDES E180 ELİTE-80.000 KM- Mercedes -...  Ankara
# 1023   MERCEDES BENZ E 250 ELITE SIFIR AYARINDA BOYASIZ  Ankara

# %%
print(df_2.gear.value_counts())
# Out:
# Otomatik Vites         567
# Yarı Otomatik Vites    412
# Düz Vites               45
# Name: gear, dtype: int64

# %%
df_2.loc[df_2.gear == "Otomatik Vites", "gear"] = "Automatic"
df_2.loc[df_2.gear == "Yarı Otomatik Vites", "gear"] = "Semi-Automatic"
df_2.loc[df_2.gear == "Düz Vites", "gear"] = "Manual"
print(df_2.gear.value_counts())
# Out:
# Automatic         567
# Semi-Automatic    412
# Manual             45
# Name: gear, dtype: int64

# %%
df_2.head(3)
# Out:
#   adver_number     brand    class_                         variant       km  \
# 0     #3870263  Mercedes  A Serisi                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A Serisi  A 180 CDI BlueEfficiency Style  102.000
# 2     #3503014  Mercedes  A Serisi                           Diğer    0.000
#
#   engine_capacity_cc engine_power    fuel            gear  adver_date  \
# 0       1301-1600 cc   Bilmiyorum  Diesel  Semi-Automatic  21/03/2021
# 1       1301-1600 cc   Bilmiyorum  Diesel       Automatic  21/03/2021
# 2       1301-1600 cc   Bilmiyorum  Diesel  Semi-Automatic  21/03/2021
#
#         from  year price_tl  \
# 0  Galeriden  2016  325950
# 1  Galeriden  2017  242000
# 2  Galeriden  2020  440000
#
#                                                title    city
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...  İzmir
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...  Konya
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...  Adana

# %%
print(df_2.class_.value_counts())
# Out:
# C           493
# E Serisi    379
# A Serisi    114
# B Serisi     38
# Name: class_, dtype: int64

# %%
df_2.loc[df_2.class_ == "C", "class_"] = "C-Class"
df_2.loc[df_2.class_ == "E Serisi", "class_"] = "E-Class"
df_2.loc[df_2.class_ == "A Serisi", "class_"] = "A-Class"
df_2.loc[df_2.class_ == "B Serisi", "class_"] = "B-Class"
df_2.head(2)
# Out:
#   adver_number     brand   class_                         variant       km  \
# 0     #3870263  Mercedes  A-Class                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A-Class  A 180 CDI BlueEfficiency Style  102.000
#
#   engine_capacity_cc engine_power    fuel            gear  adver_date  \
# 0       1301-1600 cc   Bilmiyorum  Diesel  Semi-Automatic  21/03/2021
# 1       1301-1600 cc   Bilmiyorum  Diesel       Automatic  21/03/2021
#
#         from  year price_tl  \
# 0  Galeriden  2016  325950
# 1  Galeriden  2017  242000
#
#                                                title    city
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...  İzmir
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...  Konya

# %%
print(df_2.engine_power.value_counts())
# Out:
# Bilmiyorum        977
# 126-150 BG         18
# 151-175 BG         18
# 101-125 BG          5
# 176-200 BG          3
# 76-100 BG           2
# 100 BG ve altı      1
# Name: engine_power, dtype: int64

# %%
df_2.loc[df_2.engine_power == "Bilmiyorum", "engine_power"] = "Don't know"
df_2.head()
# Out:
#   adver_number     brand   class_                         variant       km  \
# 0     #3870263  Mercedes  A-Class                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A-Class  A 180 CDI BlueEfficiency Style  102.000
# 2     #3503014  Mercedes  A-Class                           Diğer    0.000
# 3     #2259580  Mercedes  A-Class  A 180 CDI BlueEfficiency Urban  160.000
# 4     #1923116  Mercedes  A-Class                     A 180 d AMG   91.000
#
#   engine_capacity_cc engine_power    fuel            gear  adver_date  \
# 0       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
# 1       1301-1600 cc   Don't know  Diesel       Automatic  21/03/2021
# 2       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
# 3       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
# 4       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
#
#         from  year price_tl  \
# 0  Galeriden  2016  325950
# 1  Galeriden  2017  242000
# 2  Galeriden  2020  440000
# 3  Galeriden  2014  239250
# 4  Galeriden  2016  303750
#
#                                                title       city
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...     İzmir
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...     Konya
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...     Adana
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  İstanbul
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...   Denizli

# %%
df_2.loc[df_2.variant == "Diğer", "variant"] = "Other"
print(df_2.variant.value_counts())
# Out:
# Other                                     276
# C 180 AMG 7G-Tronic                        47
# E 180 Exclusive                            36
# A 180 d AMG                                31
# C 180 Komp. BlueEfficiency AMG             27
# E 180 Elite                                26
# E 200 Komp. Avantgarde                     24
# E 180 Edition E                            22
# C 180 AMG 9G-Tronic                        17
# E 180 AMG                                  17
# C 180 Exclusive                            16
# E 220 d AMG                                15
# A 180 CDI BlueEfficiency Style             15
# E 200 Elegance                             14
# C 180 BlueEfficiency Avantgarde            14
# A 180 AMG Sport                            12
# C 220 CDI Avantgarde                       11
# E 220 CDI Avantgarde                       11
# E 250 AMG 7G-Tronic                        11
# C 180 Komp. BlueEfficiency Fascination     11
# E 220 d Exclusive                          10
# C 180 Komp. BlueEfficiency Avantgarde      10
# E 220 d Avantgarde                          9
# E 180 Premium                               9
# C 180 BlueEfficiency AMG                    9
# A 180 CDI BlueEfficiency AMG                9
# E 250 CDI Edition                           9
# E 200 200                                   8
# E 250 CDI Premium                           8
# E 250 CGI AMG                               7
#                                          ...
# E 300 300                                   1
# E 320 CDI Avantgarde                        1
# E 200 CGI BlueEfficiency Prime              1
# B 150 Boyut                                 1
# E 220 CDI Start                             1
# 180 Komp. Elegance                          1
# 220 CDI                                     1
# E 350 CDI Dynamic                           1
# C 200 Avantgarde                            1
# 220 D Elegance                              1
# 180 Komp. Fascination                       1
# A 150 Avantgarde                            1
# E 230 Classic                               1
# E 240 Elegance                              1
# B 180 CDI BlueEfficiency Urban              1
# E 250 CGI Elite                             1
# 180 BlueEfficiency Fascination              1
# E 250 CDI Avantgarde                        1
# 200 Komp. Sportcoupe                        1
# C 180 Komp. BlueEfficiency Elegance         1
# E 250 BlueTEC                               1
# C 180 Style                                 1
# E 200 Classic                               1
# E 220 Classic                               1
# E 200 CDI Elegance                          1
# 200 BlueEfficiency Avantgarde               1
# A 150 Polarstar                             1
# A 180 CDI BlueEfficiency Prime              1
# E 250 CDI Elite Avantgarde                  1
# C 200 Komp. Classic                         1
# Name: variant, Length: 137, dtype: int64

# %%
df_2['variant_']=df_2['variant']

# %%
df_2.head(2)
# Out:
#   adver_number     brand   class_                         variant       km  \
# 0     #3870263  Mercedes  A-Class                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A-Class  A 180 CDI BlueEfficiency Style  102.000
#
#   engine_capacity_cc engine_power    fuel            gear  adver_date  \
# 0       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
# 1       1301-1600 cc   Don't know  Diesel       Automatic  21/03/2021
#
#         from  year price_tl  \
# 0  Galeriden  2016  325950
# 1  Galeriden  2017  242000
#
#                                                title    city  \
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...  İzmir
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...  Konya
#
#                          variant_
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 16 columns):
# adver_number          1024 non-null object
# brand                 1024 non-null object
# class_                1024 non-null object
# variant               1024 non-null object
# km                    1024 non-null float64
# engine_capacity_cc    1024 non-null object
# engine_power          1024 non-null object
# fuel                  1024 non-null object
# gear                  1024 non-null object
# adver_date            1024 non-null object
# from                  1024 non-null object
# year                  1024 non-null int64
# price_tl              1024 non-null object
# title                 1024 non-null object
# city                  1013 non-null object
# variant_              1024 non-null object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 128.1+ KB

# %%
#simple='A 180 d AMG'
#simple[:5]
df_2.variant[2][:5]
# Out:
# 'Other'

# %%
for i in range(0,len(df_2.variant_)):
    #df_2.variant_[i]=str(df_2.variant_[i])
    df_2.variant_[i]=df_2.variant_[i][:5]
df_2.variant_[5]
# Out:
# C:\Users\Noname\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 'Other'

# %%
df_2.variant_.value_counts()
# Out:
# Other    276
# C 180    179
# E 180    121
# A 180     85
# E 200     80
# E 250     70
# E 220     55
# B 180     28
# C 200     21
# E 300     16
# E 350     15
# C 220     11
# A 200      8
# B 150      7
# E 320      7
# 180 K      5
# 200 B      4
# 180 A      4
# 180-A      3
# E 270      3
# A 160      3
# B 160      3
# 220 C      3
# A 170      2
# 200 K      2
# E 230      2
# E 280      2
# A 150      2
# 200 D      2
# E 240      1
# 180 B      1
# 180 E      1
# 220 D      1
# 200 E      1
# Name: variant_, dtype: int64

# %%
df_2.loc[df_2.variant_ == "E 320", "variant_"] = "E 300"
df_2.loc[df_2.variant_ == "B 150", "variant_"] = "B 180"
df_2.loc[df_2.variant_ == "180 K", "variant_"] = "Other" 
df_2.loc[df_2.variant_ == "180 A", "variant_"] = "A 200" 
df_2.loc[df_2.variant_ == "200 B", "variant_"] = "B 180" 
df_2.loc[df_2.variant_ == "220 C", "variant_"] = "C 200" 
df_2.loc[df_2.variant_ == "180-A", "variant_"] = "A 180" 
df_2.loc[df_2.variant_ == "A 160", "variant_"] = "A 180" 
df_2.loc[df_2.variant_ == "B 160", "variant_"] = "B 180" 
df_2.loc[df_2.variant_ == "A 150", "variant_"] = "A 180" 
df_2.loc[df_2.variant_ == "200 D", "variant_"] = "Other" 
df_2.loc[df_2.variant_ == "200 K", "variant_"] = "Other" 
df_2.loc[df_2.variant_ == "A 170", "variant_"] = "A 180"
df_2.loc[df_2.variant_ == "E 230", "variant_"] = "E 220"
df_2.loc[df_2.variant_ == "E 280", "variant_"] = "E 250"
df_2.loc[df_2.variant_ == "180 B", "variant_"] = "B 180"
df_2.loc[df_2.variant_ == "E 240", "variant_"] = "E 250"
df_2.loc[df_2.variant_ == "220 D", "variant_"] = "Other"
df_2.loc[df_2.variant_ == "200 E", "variant_"] = "E 200"
df_2.loc[df_2.variant_ == "180 E", "variant_"] = "E 180"
df_2.loc[df_2.variant_ == "E 270", "variant_"] = "E 250"

df_2.variant_.value_counts()
# Out:
# Other    286
# C 180    179
# E 180    122
# A 180     95
# E 200     81
# E 250     76
# E 220     57
# B 180     43
# C 200     24
# E 300     23
# E 350     15
# A 200     12
# C 220     11
# Name: variant_, dtype: int64

# %%
df_2.head(10)
# Out:
#   adver_number     brand   class_                         variant       km  \
# 0     #3870263  Mercedes  A-Class                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A-Class  A 180 CDI BlueEfficiency Style  102.000
# 2     #3503014  Mercedes  A-Class                           Other    0.000
# 3     #2259580  Mercedes  A-Class  A 180 CDI BlueEfficiency Urban  160.000
# 4     #1923116  Mercedes  A-Class                     A 180 d AMG   91.000
# 5      #792477  Mercedes  A-Class                           Other   57.000
# 6     #2440377  Mercedes  A-Class                 A 180 AMG Sport  122.000
# 7     #3502367  Mercedes  A-Class    A 180 CDI BlueEfficiency AMG  155.000
# 8     #4461517  Mercedes  A-Class  A 180 CDI BlueEfficiency Style   70.000
# 9     #1883829  Mercedes  A-Class                     A 180 Style   75.000
#
#   engine_capacity_cc engine_power    fuel            gear  adver_date  \
# 0       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
# 1       1301-1600 cc   Don't know  Diesel       Automatic  21/03/2021
# 2       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
# 3       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
# 4       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
# 5    1300 cc ve altı   Don't know  Diesel  Semi-Automatic  21/03/2021
# 6       1301-1600 cc   Don't know  Petrol  Semi-Automatic  21/03/2021
# 7       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
# 8       1301-1600 cc   Don't know  Diesel  Semi-Automatic  21/03/2021
# 9    1300 cc ve altı   Don't know  Petrol  Semi-Automatic  21/03/2021
#
#         from  year price_tl  \
# 0  Galeriden  2016  325950
# 1  Galeriden  2017  242000
# 2  Galeriden  2020  440000
# 3  Galeriden  2014  239250
# 4  Galeriden  2016  303750
# 5  Galeriden  2017  278000
# 6  Galeriden  2015  289000
# 7  Galeriden  2014  254000
# 8  Galeriden  2016  228850
# 9  Galeriden  2013  233000
#
#                                                title       city variant_
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...     İzmir     A 180
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...     Konya     A 180
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...     Adana     Other
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  İstanbul     A 180
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...   Denizli     A 180
# 5  NEVZATOTO-57000KM-MERCEDES A180 CDI STYLE-YETK...  İstanbul     Other
# 6  ÖZGÜVEN OTODAN 2015 A180 AMG SPORT 1.6 CAM TAV...   Kocaeli     A 180
# 7  YÜCELOĞLU OTOMOTİV DEN HATA BOYA DEĞİŞEN YOK A...  Tekirdağ     A 180
# 8  2016 ORJİNAL 70 BİN KM GARANTİLİ A 180 CDİ BLU...  İstanbul     A 180
# 9  2013 MERCEDES A180 STYLE CAM TAVANLI 75.000 KM...  İstanbul     A 180

# %%
import numpy as np
df_2.engine_power.replace("Don't know", np.nan,inplace=True)
df_2.head()
# Out:
#   adver_number     brand   class_                         variant       km  \
# 0     #3870263  Mercedes  A-Class                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A-Class  A 180 CDI BlueEfficiency Style  102.000
# 2     #3503014  Mercedes  A-Class                           Other    0.000
# 3     #2259580  Mercedes  A-Class  A 180 CDI BlueEfficiency Urban  160.000
# 4     #1923116  Mercedes  A-Class                     A 180 d AMG   91.000
#
#   engine_capacity_cc engine_power    fuel            gear  adver_date  \
# 0       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021
# 1       1301-1600 cc          NaN  Diesel       Automatic  21/03/2021
# 2       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021
# 3       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021
# 4       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021
#
#         from  year price_tl  \
# 0  Galeriden  2016  325950
# 1  Galeriden  2017  242000
# 2  Galeriden  2020  440000
# 3  Galeriden  2014  239250
# 4  Galeriden  2016  303750
#
#                                                title       city variant_
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...     İzmir     A 180
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...     Konya     A 180
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...     Adana     Other
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  İstanbul     A 180
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...   Denizli     A 180

# %%
df_2=df_2.drop(['from'], axis = 1)
df_2.head()
# Out:
#   adver_number     brand   class_                         variant       km  \
# 0     #3870263  Mercedes  A-Class                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A-Class  A 180 CDI BlueEfficiency Style  102.000
# 2     #3503014  Mercedes  A-Class                           Other    0.000
# 3     #2259580  Mercedes  A-Class  A 180 CDI BlueEfficiency Urban  160.000
# 4     #1923116  Mercedes  A-Class                     A 180 d AMG   91.000
#
#   engine_capacity_cc engine_power    fuel            gear  adver_date  year  \
# 0       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021  2016
# 1       1301-1600 cc          NaN  Diesel       Automatic  21/03/2021  2017
# 2       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021  2020
# 3       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021  2014
# 4       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021  2016
#
#   price_tl                                              title       city  \
# 0  325950   2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...     İzmir
# 1  242000   Özsağlam dan 2017 Mercedes A180 CDI Style 102b...     Konya
# 2  440000   EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...     Adana
# 3  239250   A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  İstanbul
# 4  303750   AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...   Denizli
#
#   variant_
# 0    A 180
# 1    A 180
# 2    Other
# 3    A 180
# 4    A 180

# %%
df_2.engine_power.value_counts()
# Out:
# 126-150 BG        18
# 151-175 BG        18
# 101-125 BG         5
# 176-200 BG         3
# 76-100 BG          2
# 100 BG ve altı     1
# Name: engine_power, dtype: int64

# %%
df_2.loc[df_2.engine_power == "100 BG ve altı", "engine_power"] = "76-100 BG"
df_2.engine_power.value_counts()
# Out:
# 126-150 BG    18
# 151-175 BG    18
# 101-125 BG     5
# 76-100 BG      3
# 176-200 BG     3
# Name: engine_power, dtype: int64

# %%
df_2.engine_capacity_cc.value_counts()
# Out:
# 1301-1600 cc       639
# 1801-2000 cc       120
# 1300 cc ve altı     94
# 1601-1800 cc        76
# 2001-2500 cc        74
# 2501-3000 cc        14
# 3001-3500 cc         7
# Name: engine_capacity_cc, dtype: int64

# %%
df_2.loc[df_2.engine_capacity_cc == "1300 cc ve altı", "engine_capacity_cc"] = "1300 cc and lower"
df_2.engine_capacity_cc.value_counts()
# Out:
# 1301-1600 cc         639
# 1801-2000 cc         120
# 1300 cc and lower     94
# 1601-1800 cc          76
# 2001-2500 cc          74
# 2501-3000 cc          14
# 3001-3500 cc           7
# Name: engine_capacity_cc, dtype: int64

# %%
df_2.head(8)
# Out:
#   adver_number     brand   class_                         variant       km  \
# 0     #3870263  Mercedes  A-Class                     A 180 d AMG   41.541
# 1      #294428  Mercedes  A-Class  A 180 CDI BlueEfficiency Style  102.000
# 2     #3503014  Mercedes  A-Class                           Other    0.000
# 3     #2259580  Mercedes  A-Class  A 180 CDI BlueEfficiency Urban  160.000
# 4     #1923116  Mercedes  A-Class                     A 180 d AMG   91.000
# 5      #792477  Mercedes  A-Class                           Other   57.000
# 6     #2440377  Mercedes  A-Class                 A 180 AMG Sport  122.000
# 7     #3502367  Mercedes  A-Class    A 180 CDI BlueEfficiency AMG  155.000
#
#   engine_capacity_cc engine_power    fuel            gear  adver_date  year  \
# 0       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021  2016
# 1       1301-1600 cc          NaN  Diesel       Automatic  21/03/2021  2017
# 2       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021  2020
# 3       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021  2014
# 4       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021  2016
# 5  1300 cc and lower          NaN  Diesel  Semi-Automatic  21/03/2021  2017
# 6       1301-1600 cc          NaN  Petrol  Semi-Automatic  21/03/2021  2015
# 7       1301-1600 cc          NaN  Diesel  Semi-Automatic  21/03/2021  2014
#
#   price_tl                                              title       city  \
# 0  325950   2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...     İzmir
# 1  242000   Özsağlam dan 2017 Mercedes A180 CDI Style 102b...     Konya
# 2  440000   EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...     Adana
# 3  239250   A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  İstanbul
# 4  303750   AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...   Denizli
# 5  278000   NEVZATOTO-57000KM-MERCEDES A180 CDI STYLE-YETK...  İstanbul
# 6  289000   ÖZGÜVEN OTODAN 2015 A180 AMG SPORT 1.6 CAM TAV...   Kocaeli
# 7  254000   YÜCELOĞLU OTOMOTİV DEN HATA BOYA DEĞİŞEN YOK A...  Tekirdağ
#
#   variant_
# 0    A 180
# 1    A 180
# 2    Other
# 3    A 180
# 4    A 180
# 5    Other
# 6    A 180
# 7    A 180

# %%
df_2 = df_2[['adver_number',"brand","class_","variant_","km","engine_capacity_cc","engine_power","fuel","gear","adver_date","year","city","price_tl","variant","title"]]
df_2.head()
# Out:
#   adver_number     brand   class_ variant_       km engine_capacity_cc  \
# 0     #3870263  Mercedes  A-Class    A 180   41.541       1301-1600 cc
# 1      #294428  Mercedes  A-Class    A 180  102.000       1301-1600 cc
# 2     #3503014  Mercedes  A-Class    Other    0.000       1301-1600 cc
# 3     #2259580  Mercedes  A-Class    A 180  160.000       1301-1600 cc
# 4     #1923116  Mercedes  A-Class    A 180   91.000       1301-1600 cc
#
#   engine_power    fuel            gear  adver_date  year       city price_tl  \
# 0          NaN  Diesel  Semi-Automatic  21/03/2021  2016     İzmir   325950
# 1          NaN  Diesel       Automatic  21/03/2021  2017     Konya   242000
# 2          NaN  Diesel  Semi-Automatic  21/03/2021  2020     Adana   440000
# 3          NaN  Diesel  Semi-Automatic  21/03/2021  2014  İstanbul   239250
# 4          NaN  Diesel  Semi-Automatic  21/03/2021  2016   Denizli   303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...

# %%
df_2.year.value_counts()
# Out:
# 2016    170
# 2017    132
# 2015    121
# 2018     96
# 2011     67
# 2014     66
# 2012     57
# 2013     48
# 2010     43
# 2020     40
# 2008     18
# 1996     17
# 2001     15
# 2009     14
# 2004     13
# 1998     13
# 2006     12
# 1994     12
# 1997     10
# 2007     10
# 2003     10
# 2005     10
# 1995      8
# 2002      5
# 2000      5
# 1993      3
# 1987      2
# 1989      1
# 1986      1
# 2021      1
# 1990      1
# 1999      1
# 2019      1
# 1985      1
# Name: year, dtype: int64

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 15 columns):
# adver_number          1024 non-null object
# brand                 1024 non-null object
# class_                1024 non-null object
# variant_              1024 non-null object
# km                    1024 non-null float64
# engine_capacity_cc    1024 non-null object
# engine_power          47 non-null object
# fuel                  1024 non-null object
# gear                  1024 non-null object
# adver_date            1024 non-null object
# year                  1024 non-null int64
# city                  1013 non-null object
# price_tl              1024 non-null object
# variant               1024 non-null object
# title                 1024 non-null object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 120.1+ KB

# %%
df_2["price_tl"] = df_2['price_tl'].astype('int64')
df_2.dtypes
# Out:
# adver_number           object
# brand                  object
# class_                 object
# variant_               object
# km                    float64
# engine_capacity_cc     object
# engine_power           object
# fuel                   object
# gear                   object
# adver_date             object
# year                    int64
# city                   object
# price_tl                int64
# variant                object
# title                  object
# dtype: object

# %%
df_2.head(5)
# Out:
#   adver_number     brand   class_ variant_       km engine_capacity_cc  \
# 0     #3870263  Mercedes  A-Class    A 180   41.541       1301-1600 cc
# 1      #294428  Mercedes  A-Class    A 180  102.000       1301-1600 cc
# 2     #3503014  Mercedes  A-Class    Other    0.000       1301-1600 cc
# 3     #2259580  Mercedes  A-Class    A 180  160.000       1301-1600 cc
# 4     #1923116  Mercedes  A-Class    A 180   91.000       1301-1600 cc
#
#   engine_power    fuel            gear  adver_date  year       city  price_tl  \
# 0          NaN  Diesel  Semi-Automatic  21/03/2021  2016     İzmir     325950
# 1          NaN  Diesel       Automatic  21/03/2021  2017     Konya     242000
# 2          NaN  Diesel  Semi-Automatic  21/03/2021  2020     Adana     440000
# 3          NaN  Diesel  Semi-Automatic  21/03/2021  2014  İstanbul     239250
# 4          NaN  Diesel  Semi-Automatic  21/03/2021  2016   Denizli     303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...

# %%
df_2=df_2.drop(['engine_power'], axis = 1)
df_2.head()
# Out:
#   adver_number     brand   class_ variant_       km engine_capacity_cc  \
# 0     #3870263  Mercedes  A-Class    A 180   41.541       1301-1600 cc
# 1      #294428  Mercedes  A-Class    A 180  102.000       1301-1600 cc
# 2     #3503014  Mercedes  A-Class    Other    0.000       1301-1600 cc
# 3     #2259580  Mercedes  A-Class    A 180  160.000       1301-1600 cc
# 4     #1923116  Mercedes  A-Class    A 180   91.000       1301-1600 cc
#
#      fuel            gear  adver_date  year       city  price_tl  \
# 0  Diesel  Semi-Automatic  21/03/2021  2016     İzmir     325950
# 1  Diesel       Automatic  21/03/2021  2017     Konya     242000
# 2  Diesel  Semi-Automatic  21/03/2021  2020     Adana     440000
# 3  Diesel  Semi-Automatic  21/03/2021  2014  İstanbul     239250
# 4  Diesel  Semi-Automatic  21/03/2021  2016   Denizli     303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...

# %%
df_2[df_2.city.isnull()]
# Out:
#     adver_number     brand   class_ variant_     km engine_capacity_cc  \
# 122     #4769259  Mercedes  B-Class    B 180   74.0       1301-1600 cc
# 139     #4492778  Mercedes  B-Class    B 180   74.0       1301-1600 cc
# 155     #2761315  Mercedes  C-Class    Other   38.0       1301-1600 cc
# 338     #2870822  Mercedes  C-Class    C 180  205.0       1601-1800 cc
# 438     #1579393  Mercedes  C-Class    C 180   90.0       1301-1600 cc
# 485     #4668935  Mercedes  C-Class    Other   38.0       1301-1600 cc
# 510     #3809063  Mercedes  C-Class    C 180   98.0       1301-1600 cc
# 603     #4389159  Mercedes  C-Class    C 180   98.0       1301-1600 cc
# 612     #3484769  Mercedes  C-Class    Other   38.0       1301-1600 cc
# 722     #4742299  Mercedes  E-Class    E 250  257.0       1601-1800 cc
# 998      #862681  Mercedes  E-Class    E 200  272.0       1801-2000 cc
#
#        fuel            gear  adver_date  year city  price_tl  \
# 122  Petrol  Semi-Automatic  21/03/2021  2015  NaN    253500
# 139  Petrol  Semi-Automatic  05/02/2021  2015  NaN    253500
# 155  Diesel       Automatic  21/03/2021  2018  NaN    479900
# 338  Petrol  Semi-Automatic  15/02/2021  2011  NaN    192000
# 438  Petrol       Automatic  24/01/2021  2016  NaN    359900
# 485  Diesel       Automatic  24/01/2021  2018  NaN    499900
# 510  Petrol  Semi-Automatic  06/01/2021  2014  NaN    369000
# 603  Petrol  Semi-Automatic  05/02/2021  2014  NaN    367500
# 612  Diesel       Automatic  15/02/2021  2018  NaN    492900
# 722  Petrol       Automatic  21/03/2021  2011  NaN    330000
# 998  Petrol          Manual  15/02/2021  1996  NaN    101000
#
#                              variant  \
# 122       B 180 BlueEfficiency Urban
# 139       B 180 BlueEfficiency Urban
# 155                            Other
# 338  C 180 BlueEfficiency Avantgarde
# 438              C 180 AMG 7G-Tronic
# 485                            Other
# 510                  C 180 Exclusive
# 603                  C 180 Exclusive
# 612                            Other
# 722            E 250 CGI Premium AMG
# 998                   E 200 Elegance
#
#                                                  title
# 122  2015 B180 1.6 122HP URBAN CAM TAVAN 74.000KM M...
# 139  2015 B180 1.6 122HP URBAN CAM TAVAN 74.000KM M...
# 155  ORAS DAN 2018 MODEL MERCEDES C200 D RECORE KOL...
# 338  YENİ KASA 2011 C 180 AVANTGARDE 1.8 156 BG 7G-...
# 438  ORAS DAN 2016 MODEL MERCEDES - BENZ C 180 AMG ...
# 485  ORAS DAN 2018 MODEL MERCEDES C200 D RECORE KOL...
# 510  POLAT TAN 2014 MODEL MERCEDES C180 EXCLUSİVE İ...
# 603  POLAT TAN 2014 MODEL MERCEDES C180 EXCLUSİVE İ...
# 612  ORAS DAN 2018 MODEL MERCEDES C200 D RECORE KOL...
# 722  2011 MERCEDES E 250 PREMİUM AMG BOYASIZ HATASI...
# 998  BULUT OTOMOTIVDEN TEMİZ SORUNSUZ E200 ELEGANCE...

# %%
df_2['city'] = df['city'].replace(np.nan, 'İstanbul')
df_2.head()
# Out:
#   adver_number     brand   class_ variant_       km engine_capacity_cc  \
# 0     #3870263  Mercedes  A-Class    A 180   41.541       1301-1600 cc
# 1      #294428  Mercedes  A-Class    A 180  102.000       1301-1600 cc
# 2     #3503014  Mercedes  A-Class    Other    0.000       1301-1600 cc
# 3     #2259580  Mercedes  A-Class    A 180  160.000       1301-1600 cc
# 4     #1923116  Mercedes  A-Class    A 180   91.000       1301-1600 cc
#
#      fuel            gear  adver_date  year       city  price_tl  \
# 0  Diesel  Semi-Automatic  21/03/2021  2016     İzmir     325950
# 1  Diesel       Automatic  21/03/2021  2017     Konya     242000
# 2  Diesel  Semi-Automatic  21/03/2021  2020     Adana     440000
# 3  Diesel  Semi-Automatic  21/03/2021  2014  İstanbul     239250
# 4  Diesel  Semi-Automatic  21/03/2021  2016   Denizli     303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 14 columns):
# adver_number          1024 non-null object
# brand                 1024 non-null object
# class_                1024 non-null object
# variant_              1024 non-null object
# km                    1024 non-null float64
# engine_capacity_cc    1024 non-null object
# fuel                  1024 non-null object
# gear                  1024 non-null object
# adver_date            1024 non-null object
# year                  1024 non-null int64
# city                  1024 non-null object
# price_tl              1024 non-null int64
# variant               1024 non-null object
# title                 1024 non-null object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 112.1+ KB

# %%
df_2.head(30)
# Out:
#    adver_number     brand   class_ variant_         km engine_capacity_cc  \
# 0      #3870263  Mercedes  A-Class    A 180     41.541       1301-1600 cc
# 1       #294428  Mercedes  A-Class    A 180    102.000       1301-1600 cc
# 2      #3503014  Mercedes  A-Class    Other      0.000       1301-1600 cc
# 3      #2259580  Mercedes  A-Class    A 180    160.000       1301-1600 cc
# 4      #1923116  Mercedes  A-Class    A 180     91.000       1301-1600 cc
# 5       #792477  Mercedes  A-Class    Other     57.000  1300 cc and lower
# 6      #2440377  Mercedes  A-Class    A 180    122.000       1301-1600 cc
# 7      #3502367  Mercedes  A-Class    A 180    155.000       1301-1600 cc
# 8      #4461517  Mercedes  A-Class    A 180     70.000       1301-1600 cc
# 9      #1883829  Mercedes  A-Class    A 180     75.000  1300 cc and lower
# 10      #832596  Mercedes  A-Class    A 180    178.000       1301-1600 cc
# 11     #1218883  Mercedes  A-Class    A 180     76.500       1301-1600 cc
# 12     #3453861  Mercedes  A-Class    A 180    138.000       1301-1600 cc
# 13     #4643213  Mercedes  A-Class    A 180     40.000  1300 cc and lower
# 14     #3912328  Mercedes  A-Class    A 180      6.000       1301-1600 cc
# 15     #2305052  Mercedes  A-Class    A 180     95.900       1301-1600 cc
# 16     #1809488  Mercedes  A-Class    A 200     41.009       1301-1600 cc
# 17     #1656574  Mercedes  A-Class    A 180     93.500       1301-1600 cc
# 18     #4443610  Mercedes  A-Class    A 180    138.000       1301-1600 cc
# 19     #4422963  Mercedes  A-Class    A 180     82.000       1301-1600 cc
# 20     #4777448  Mercedes  A-Class    A 180     34.000       1301-1600 cc
# 21     #3952821  Mercedes  A-Class    Other    900.000       1301-1600 cc
# 22     #4420263  Mercedes  A-Class    A 180     77.000       1301-1600 cc
# 23      #424581  Mercedes  A-Class    Other  46875.000  1300 cc and lower
# 24      #878261  Mercedes  A-Class    A 180     42.000       1301-1600 cc
# 25     #3792309  Mercedes  A-Class    A 180    145.000       1301-1600 cc
# 26     #1730879  Mercedes  A-Class    A 180     75.000       1301-1600 cc
# 27     #4561054  Mercedes  A-Class    A 180     75.500       1301-1600 cc
# 28     #2645387  Mercedes  A-Class    A 180     56.000       1301-1600 cc
# 29     #3134290  Mercedes  A-Class    A 180     58.000       1301-1600 cc
#
#       fuel            gear  adver_date  year        city  price_tl  \
# 0   Diesel  Semi-Automatic  21/03/2021  2016      İzmir     325950
# 1   Diesel       Automatic  21/03/2021  2017      Konya     242000
# 2   Diesel  Semi-Automatic  21/03/2021  2020      Adana     440000
# 3   Diesel  Semi-Automatic  21/03/2021  2014   İstanbul     239250
# 4   Diesel  Semi-Automatic  21/03/2021  2016    Denizli     303750
# 5   Diesel  Semi-Automatic  21/03/2021  2017   İstanbul     278000
# 6   Petrol  Semi-Automatic  21/03/2021  2015    Kocaeli     289000
# 7   Diesel  Semi-Automatic  21/03/2021  2014   Tekirdağ     254000
# 8   Diesel  Semi-Automatic  21/03/2021  2016   İstanbul     228850
# 9   Petrol  Semi-Automatic  21/03/2021  2013   İstanbul     233000
# 10  Petrol  Semi-Automatic  21/03/2021  2007      Konya     104999
# 11  Diesel  Semi-Automatic  21/03/2021  2016      İzmir     306500
# 12  Diesel  Semi-Automatic  21/03/2021  2015   İstanbul     262950
# 13  Petrol  Semi-Automatic  21/03/2021  2013   İstanbul     227000
# 14  Diesel  Semi-Automatic  21/03/2021  2020   İstanbul     452500
# 15  Diesel  Semi-Automatic  21/03/2021  2015   İstanbul     269000
# 16  Petrol  Semi-Automatic  21/03/2021  2017   İstanbul     335000
# 17  Diesel       Automatic  21/03/2021  2017      Konya     257000
# 18  Diesel  Semi-Automatic  21/03/2021  2016   İstanbul     299900
# 19  Diesel  Semi-Automatic  21/03/2021  2016    Trabzon     299000
# 20  Petrol  Semi-Automatic  21/03/2021  2016    Denizli     326900
# 21  Petrol  Semi-Automatic  21/03/2021  2020      Adana     439900
# 22  Diesel  Semi-Automatic  21/03/2021  2015   İstanbul     278950
# 23  Diesel       Automatic  21/03/2021  2017       Ordu     307000
# 24  Diesel  Semi-Automatic  21/03/2021  2015  Gaziantep     287500
# 25  Diesel  Semi-Automatic  21/03/2021  2015      Düzce     220900
# 26  Petrol  Semi-Automatic  21/03/2021  2014  Zonguldak     258000
# 27  Diesel  Semi-Automatic  21/03/2021  2016  Şanlıurfa     255000
# 28  Diesel  Semi-Automatic  21/03/2021  2016      Aydın     309500
# 29  Petrol  Semi-Automatic  21/03/2021  2014   İstanbul     197500
#
#                            variant  \
# 0                      A 180 d AMG
# 1   A 180 CDI BlueEfficiency Style
# 2                            Other
# 3   A 180 CDI BlueEfficiency Urban
# 4                      A 180 d AMG
# 5                            Other
# 6                  A 180 AMG Sport
# 7     A 180 CDI BlueEfficiency AMG
# 8   A 180 CDI BlueEfficiency Style
# 9                      A 180 Style
# 10                 A 150 Polarstar
# 11                     A 180 d AMG
# 12    A 180 CDI BlueEfficiency AMG
# 13                     A 180 Style
# 14                     A 180 d AMG
# 15    A 180 CDI BlueEfficiency AMG
# 16        A 200 BlueEfficiency AMG
# 17  A 180 CDI BlueEfficiency Style
# 18                     A 180 d AMG
# 19                     A 180 d AMG
# 20                 A 180 AMG Sport
# 21                           Other
# 22    A 180 CDI BlueEfficiency AMG
# 23                           Other
# 24  A 180 CDI BlueEfficiency Style
# 25  A 180 CDI BlueEfficiency Style
# 26                 A 180 AMG Sport
# 27                     A 180 d AMG
# 28                     A 180 d AMG
# 29                     A 180 Urban
#
#                                                 title
# 0   2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...
# 1   Özsağlam dan 2017 Mercedes A180 CDI Style 102b...
# 2   EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...
# 3   A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...
# 4   AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...
# 5   NEVZATOTO-57000KM-MERCEDES A180 CDI STYLE-YETK...
# 6   ÖZGÜVEN OTODAN 2015 A180 AMG SPORT 1.6 CAM TAV...
# 7   YÜCELOĞLU OTOMOTİV DEN HATA BOYA DEĞİŞEN YOK A...
# 8   2016 ORJİNAL 70 BİN KM GARANTİLİ A 180 CDİ BLU...
# 9   2013 MERCEDES A180 STYLE CAM TAVANLI 75.000 KM...
# 10  PARK AUTO DAN 178.000 KM OTOMATİK A150 Mercede...
# 11  BOYASIZ HATASIZ 2016 MERCEDES A180d AMG 75.600...
# 12  ULAŞ AUTO DAN 2015 MERCEDES A180 CDI AMG HATAS...
# 13  2013 A 180 STYLE 40.000 KM DE HATASIZ-BOYASIZ ...
# 14  DÜZEN AUTO AUTOPİA 2020 A180d AMG TEKNOLOJİ PL...
# 15  CARMIX MOTORS 2015 MERCEDES BENZ A180 CDI AMG ...
# 16  GARAGE 2017 MERCEDES BENZ A 200 AMG CAM TAVAN ...
# 17  Özsağlam dan 2017 Mercedes A180 CDI Style 93bi...
# 18  EMEFE MOTORS 2016 A180d AMG 7G-DCT C. TAVN KAR...
# 19  2016 MERCEDES A180 D AMG HATASIZ-BOYASIZ-TRAME...
# 20  VEFA-2016 MODEL MERCEDES A 180 BLUEEFFICIENCY ...
# 21  2O2O-MODEL 9OO-KM DE A-18O BLACKART BEJ-DERİ K...
# 22  CİVAN 2015 MERCEDES-BENZ A180 CDI AMG C.TAV-BO...
# 23  EKSTRA DERİ KOLTUK AKILLI ANAHTAR SUNROOF ÖZEL...
# 24  2015 BOYASIZ A 180 CDI STYLE 7 G-DCT XENON CM ...
# 25  45 BİN PEŞİNATLA DİZEL OTOMATİK 2015 Mercedes ...
# 26  2014 MODEL MERCEDES A180 AMG HATASIZ-BOYASIZ-T...
# 27  KENT AUTO 2016 MODEL A 180d GECE PAKETİ CAM TA...
# 28  HATASIZ-DEĞİŞENSİZ 2016 MAKYAJLI KASA A180d AM...
# 29  DS CAR DAN 2014 MODEL A180 BENZİN OTOMATİK URB...

# %%
df_2.loc[df_2.city == "İstanbul ", "city"] = 'Istanbul'
df_2.loc[df_2.city == "İstanbul", "city"] = 'Istanbul'
df_2.loc[df_2.city == "İzmir ", "city"] = 'Izmir'
df_2.loc[df_2.city == "İzmir", "city"] = 'Izmir'
df_2.loc[df_2.city == "Tekirdağ ", "city"] = 'Tekirdag'
df_2.loc[df_2.city == "Tekirdağ", "city"] = 'Tekirdag'
df_2.head()
# Out:
#   adver_number     brand   class_ variant_       km engine_capacity_cc  \
# 0     #3870263  Mercedes  A-Class    A 180   41.541       1301-1600 cc
# 1      #294428  Mercedes  A-Class    A 180  102.000       1301-1600 cc
# 2     #3503014  Mercedes  A-Class    Other    0.000       1301-1600 cc
# 3     #2259580  Mercedes  A-Class    A 180  160.000       1301-1600 cc
# 4     #1923116  Mercedes  A-Class    A 180   91.000       1301-1600 cc
#
#      fuel            gear  adver_date  year      city  price_tl  \
# 0  Diesel  Semi-Automatic  21/03/2021  2016     Izmir    325950
# 1  Diesel       Automatic  21/03/2021  2017    Konya     242000
# 2  Diesel  Semi-Automatic  21/03/2021  2020    Adana     440000
# 3  Diesel  Semi-Automatic  21/03/2021  2014  Istanbul    239250
# 4  Diesel  Semi-Automatic  21/03/2021  2016  Denizli     303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...

# %%
df_2.head()
# Out:
#   adver_number     brand   class_ variant_       km engine_capacity_cc  \
# 0     #3870263  Mercedes  A-Class    A 180   41.541       1301-1600 cc
# 1      #294428  Mercedes  A-Class    A 180  102.000       1301-1600 cc
# 2     #3503014  Mercedes  A-Class    Other    0.000       1301-1600 cc
# 3     #2259580  Mercedes  A-Class    A 180  160.000       1301-1600 cc
# 4     #1923116  Mercedes  A-Class    A 180   91.000       1301-1600 cc
#
#      fuel            gear  adver_date  year      city  price_tl  \
# 0  Diesel  Semi-Automatic  21/03/2021  2016     Izmir    325950
# 1  Diesel       Automatic  21/03/2021  2017    Konya     242000
# 2  Diesel  Semi-Automatic  21/03/2021  2020    Adana     440000
# 3  Diesel  Semi-Automatic  21/03/2021  2014  Istanbul    239250
# 4  Diesel  Semi-Automatic  21/03/2021  2016  Denizli     303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...

# %%
df_2.to_csv(r'MercedesTidyData.csv', index = False)

# %%
df_3=pd.read_csv('MercedesTidyData.csv')
df_3.head(5)
# Out:
#   adver_number     brand   class_ variant_       km engine_capacity_cc  \
# 0     #3870263  Mercedes  A-Class    A 180   41.541       1301-1600 cc
# 1      #294428  Mercedes  A-Class    A 180  102.000       1301-1600 cc
# 2     #3503014  Mercedes  A-Class    Other    0.000       1301-1600 cc
# 3     #2259580  Mercedes  A-Class    A 180  160.000       1301-1600 cc
# 4     #1923116  Mercedes  A-Class    A 180   91.000       1301-1600 cc
#
#      fuel            gear  adver_date  year      city  price_tl  \
# 0  Diesel  Semi-Automatic  21/03/2021  2016     Izmir    325950
# 1  Diesel       Automatic  21/03/2021  2017    Konya     242000
# 2  Diesel  Semi-Automatic  21/03/2021  2020    Adana     440000
# 3  Diesel  Semi-Automatic  21/03/2021  2014  Istanbul    239250
# 4  Diesel  Semi-Automatic  21/03/2021  2016  Denizli     303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...

# %%
df_3["km"] = df_3['km'].astype('object')
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 14 columns):
# adver_number          1024 non-null object
# brand                 1024 non-null object
# class_                1024 non-null object
# variant_              1024 non-null object
# km                    1024 non-null object
# engine_capacity_cc    1024 non-null object
# fuel                  1024 non-null object
# gear                  1024 non-null object
# adver_date            1024 non-null object
# year                  1024 non-null int64
# city                  1024 non-null object
# price_tl              1024 non-null int64
# variant               1024 non-null object
# title                 1024 non-null object
# dtypes: int64(2), object(12)
# memory usage: 112.1+ KB

# %%
str(df_3.km[0])
# Out:
# '41.541000000000004'

# %%
i=46875.000
i=str(i)
listem=i.split(".")
i=listem[0]
#if(len(str(i))>=4):
#    b=str(i)[::-1]
#    c=str(b)[3:1]
#    i=str(c[::-1])
#print(len(str(i))>=4)
b=str(i)[::-1]
c=str(b)[3:]
i=str(c[::-1])
print(i)
# Out:
# 46

# %%
a='46875.000'
str(a)[:3]
# Out:
# '468'

# %%
a=46875
if(len(str(a))>=3):
    b=str(a)[::-1]
    c=str(b)[3:]
    print(c[::-1])
    
    46875.000
# Out:
# 46

# %%
for i in range(0,len(df_3.km)):
    df_3.km[i]=str(df_3.km[i])
    listem=df_3.km[i].split(".")
    df_3.km[i]=listem[0]
    if(len(str(listem[0]))>=4):
        b=str(df_3.km[i])[::-1]
        c=str(b)[3:]
        df_3.km[i]=str(c[::-1])
    df_3.km[i]=str(df_3.km[i])+"000"
# Out:
# C:\Users\Noname\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Noname\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Noname\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Noname\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 14 columns):
# adver_number          1024 non-null object
# brand                 1024 non-null object
# class_                1024 non-null object
# variant_              1024 non-null object
# km                    1024 non-null object
# engine_capacity_cc    1024 non-null object
# fuel                  1024 non-null object
# gear                  1024 non-null object
# adver_date            1024 non-null object
# year                  1024 non-null int64
# city                  1024 non-null object
# price_tl              1024 non-null int64
# variant               1024 non-null object
# title                 1024 non-null object
# dtypes: int64(2), object(12)
# memory usage: 112.1+ KB

# %%
df_3.head(5)
# Out:
#   adver_number     brand   class_ variant_      km engine_capacity_cc    fuel  \
# 0     #3870263  Mercedes  A-Class    A 180   41000       1301-1600 cc  Diesel
# 1      #294428  Mercedes  A-Class    A 180  102000       1301-1600 cc  Diesel
# 2     #3503014  Mercedes  A-Class    Other    0000       1301-1600 cc  Diesel
# 3     #2259580  Mercedes  A-Class    A 180  160000       1301-1600 cc  Diesel
# 4     #1923116  Mercedes  A-Class    A 180   91000       1301-1600 cc  Diesel
#
#              gear  adver_date  year      city  price_tl  \
# 0  Semi-Automatic  21/03/2021  2016     Izmir    325950
# 1       Automatic  21/03/2021  2017    Konya     242000
# 2  Semi-Automatic  21/03/2021  2020    Adana     440000
# 3  Semi-Automatic  21/03/2021  2014  Istanbul    239250
# 4  Semi-Automatic  21/03/2021  2016  Denizli     303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...

# %%
for i in range(0,len(df_3.km)):
    df_3.city[i]=df_3.city[i].replace(" ","")
# Out:
# C:\Users\Noname\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_3.city.value_counts().head()
# Out:
# Istanbul     507
# Ankara        69
# Konya         44
# Gaziantep     43
# Izmir         42
# Name: city, dtype: int64

# %%
df_3.to_json(r'MercedesTidyData-.json')

# %%
df_3.to_csv(r'MercedesTidyData.csv', index = False)

# %%
df_4=pd.read_csv('MercedesTidyData.csv')
pd.DataFrame(df_4.city.value_counts()).head()
# Out:
#            city
# Istanbul    507
# Ankara       69
# Konya        44
# Gaziantep    43
# Izmir        42

# %%
df_4.head()
# Out:
#   adver_number     brand   class_ variant_      km engine_capacity_cc    fuel  \
# 0     #3870263  Mercedes  A-Class    A 180   41000       1301-1600 cc  Diesel
# 1      #294428  Mercedes  A-Class    A 180  102000       1301-1600 cc  Diesel
# 2     #3503014  Mercedes  A-Class    Other       0       1301-1600 cc  Diesel
# 3     #2259580  Mercedes  A-Class    A 180  160000       1301-1600 cc  Diesel
# 4     #1923116  Mercedes  A-Class    A 180   91000       1301-1600 cc  Diesel
#
#              gear  adver_date  year      city  price_tl  \
# 0  Semi-Automatic  21/03/2021  2016     Izmir    325950
# 1       Automatic  21/03/2021  2017     Konya    242000
# 2  Semi-Automatic  21/03/2021  2020     Adana    440000
# 3  Semi-Automatic  21/03/2021  2014  Istanbul    239250
# 4  Semi-Automatic  21/03/2021  2016   Denizli    303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...

# %%
df_4['city_']=df_4.city
df_4.head()
# Out:
#   adver_number     brand   class_ variant_      km engine_capacity_cc    fuel  \
# 0     #3870263  Mercedes  A-Class    A 180   41000       1301-1600 cc  Diesel
# 1      #294428  Mercedes  A-Class    A 180  102000       1301-1600 cc  Diesel
# 2     #3503014  Mercedes  A-Class    Other       0       1301-1600 cc  Diesel
# 3     #2259580  Mercedes  A-Class    A 180  160000       1301-1600 cc  Diesel
# 4     #1923116  Mercedes  A-Class    A 180   91000       1301-1600 cc  Diesel
#
#              gear  adver_date  year      city  price_tl  \
# 0  Semi-Automatic  21/03/2021  2016     Izmir    325950
# 1       Automatic  21/03/2021  2017     Konya    242000
# 2  Semi-Automatic  21/03/2021  2020     Adana    440000
# 3  Semi-Automatic  21/03/2021  2014  Istanbul    239250
# 4  Semi-Automatic  21/03/2021  2016   Denizli    303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title     city_
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...     Izmir
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...     Konya
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...     Adana
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  Istanbul
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...   Denizli

# %%
for i in range(0,len(df_4.city_)):
    if (df_4.city[i] =='Istanbul'):
        pass
    else:
        df_4.city[i]='Other'
# Out:
# C:\Users\Noname\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_4.head(5)
# Out:
#   adver_number     brand   class_ variant_      km engine_capacity_cc    fuel  \
# 0     #3870263  Mercedes  A-Class    A 180   41000       1301-1600 cc  Diesel
# 1      #294428  Mercedes  A-Class    A 180  102000       1301-1600 cc  Diesel
# 2     #3503014  Mercedes  A-Class    Other       0       1301-1600 cc  Diesel
# 3     #2259580  Mercedes  A-Class    A 180  160000       1301-1600 cc  Diesel
# 4     #1923116  Mercedes  A-Class    A 180   91000       1301-1600 cc  Diesel
#
#              gear  adver_date  year      city  price_tl  \
# 0  Semi-Automatic  21/03/2021  2016     Other    325950
# 1       Automatic  21/03/2021  2017     Other    242000
# 2  Semi-Automatic  21/03/2021  2020     Other    440000
# 3  Semi-Automatic  21/03/2021  2014  Istanbul    239250
# 4  Semi-Automatic  21/03/2021  2016     Other    303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title     city_
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...     Izmir
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...     Konya
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...     Adana
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  Istanbul
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...   Denizli

# %%
df_4.to_csv(r'MercedesTidyData.csv', index = False)

# %%
df_4.head()
# Out:
#   adver_number     brand   class_ variant_      km engine_capacity_cc    fuel  \
# 0     #3870263  Mercedes  A-Class    A 180   41000       1301-1600 cc  Diesel
# 1      #294428  Mercedes  A-Class    A 180  102000       1301-1600 cc  Diesel
# 2     #3503014  Mercedes  A-Class    Other       0       1301-1600 cc  Diesel
# 3     #2259580  Mercedes  A-Class    A 180  160000       1301-1600 cc  Diesel
# 4     #1923116  Mercedes  A-Class    A 180   91000       1301-1600 cc  Diesel
#
#              gear  adver_date  year      city  price_tl  \
# 0  Semi-Automatic  21/03/2021  2016     Other    325950
# 1       Automatic  21/03/2021  2017     Other    242000
# 2  Semi-Automatic  21/03/2021  2020     Other    440000
# 3  Semi-Automatic  21/03/2021  2014  Istanbul    239250
# 4  Semi-Automatic  21/03/2021  2016     Other    303750
#
#                           variant  \
# 0                     A 180 d AMG
# 1  A 180 CDI BlueEfficiency Style
# 2                           Other
# 3  A 180 CDI BlueEfficiency Urban
# 4                     A 180 d AMG
#
#                                                title     city_
# 0  2016 A180dAMG MAKYAJLI KASA CAM TAVAN XENON KE...     Izmir
# 1  Özsağlam dan 2017 Mercedes A180 CDI Style 102b...     Konya
# 2  EROĞLU 0.KM 2020 MERCEDES A180d TECHNOLOGY CAM...     Adana
# 3  A180 CDI BlueEFFICIENCY URBAN.. DEĞİŞENSİZ-İÇİ...  Istanbul
# 4  AZİM OTOMOTİV DEN İLK SAHİBİN DEN 2016 A 180 d...   Denizli
